# %% [markdown]
# # Cleaning US Census Data

# %% [markdown]
# You just got hired as a Data Analyst at the Census Bureau, which collects census data and creates interesting visualizations and insights from it.
#
# The person who had your job before you left you all the data they had for the most recent census. It is in multiple `csv` files. They didn't use pandas, they would just look through these `csv` files manually whenever they wanted to find something. Sometimes they would copy and paste certain numbers into Excel to make charts.
#
# The thought of it makes you shiver. This is not scalable or repeatable.
#
# Your boss wants you to make some scatterplots and histograms by the end of the day. Can you get this data into `pandas` and into reasonable shape so that you can make these histograms?

# %% [markdown]
# ## Inspect the Data!

# %% [markdown]
# 1. The first visualization your boss wants you to make is a scatterplot that shows average income in a state vs proportion of women in that state.
#
#    Open some of the census `csv` files that came with the kit you downloaded. How are they named? What kind of information do they hold? Will they help us make this graph?

# %%
import glob
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 
import seaborn as sns
def read_df(df):
    return pd.read_csv(df)
df1 = read_df('states0.csv')
df1
df8 = read_df('states8.csv')
df8
# Out:
#    Unnamed: 0           State  TotalPop Hispanic   White   Black Native  \
# 0           0    Rhode Island   1053661   13.36%  74.33%   5.68%  0.35%
# 1           1  South Carolina   4777576    5.06%  62.89%  28.75%  0.29%
# 2           2    South Dakota    843190    3.24%  82.50%   1.42%  9.42%
# 3           3       Tennessee   6499615    4.72%  73.49%  18.28%  0.23%
# 4           4           Texas  26538614   38.05%  44.69%  11.65%  0.26%
# 5           5            Utah   2903379   13.47%  79.41%   1.02%  1.08%
#
#    Asian Pacific       Income            GenderPop
# 0  3.25%   0.04%  $59,125.27       510388M_543273F
# 1  1.25%   0.05%  $46,296.81     2322409M_2455167F
# 2  1.02%   0.04%  $51,805.41       423477M_419713F
# 3  1.41%   0.04%  $47,328.08     3167756M_3331859F
# 4  3.67%   0.07%  $55,874.52   13171316M_13367298F
# 5  2.20%   0.83%  $63,488.92     1459229M_1444150F

# %% [markdown]
# 2. It will be easier to inspect this data once we have it in a DataFrame. You can't even call `.head()` on these `csv`s! How are you supposed to read them?
#
#    Using `glob`, loop through the census files available and load them into DataFrames. Then, concatenate all of those DataFrames together into one DataFrame, called something like `us_census`.

# %%
files = glob.glob('states[0-9].csv')
df_list = []
for file in files:
    df = read_df(file)
    df_list.append(df)
df = pd.concat(df_list).reset_index(drop=True)
columns = list(df.columns)
columns.remove('Unnamed: 0')
df = df[columns]
df
# Out:
#                    State  TotalPop Hispanic   White   Black  Native   Asian  \
# 0           Rhode Island   1053661   13.36%  74.33%   5.68%   0.35%   3.25%
# 1         South Carolina   4777576    5.06%  62.89%  28.75%   0.29%   1.25%
# 2           South Dakota    843190    3.24%  82.50%   1.42%   9.42%   1.02%
# 3              Tennessee   6499615    4.72%  73.49%  18.28%   0.23%   1.41%
# 4                  Texas  26538614   38.05%  44.69%  11.65%   0.26%   3.67%
# 5                   Utah   2903379   13.47%  79.41%   1.02%   1.08%   2.20%
# 6                   Utah   2903379   13.47%  79.41%   1.02%   1.08%   2.20%
# 7                Vermont    626604    1.61%  93.98%   0.98%   0.30%   1.24%
# 8               Virginia   8256630    8.01%  63.27%  20.18%   0.21%   5.46%
# 9             Washington   6985464   11.14%  72.04%   3.38%   1.41%   7.02%
# 10         West Virginia   1851420    1.29%  92.18%   3.66%   0.15%   0.68%
# ...

# %% [markdown]
# 3. Look at the `.columns` and the `.dtypes` of the `us_census` DataFrame. Are those datatypes going to hinder you as you try to make histograms?

# %%
print(df.dtypes)
# Out:
# State        object
# TotalPop      int64
# Hispanic     object
# White        object
# Black        object
# Native       object
# Asian        object
# Pacific      object
# Income       object
# GenderPop    object
# dtype: object

# %% [markdown]
# 4. Look at the `head()` of the DataFrame so that you can understand why some of these `dtypes` are objects instead of integers or floats.
#
#    Start to make a plan for how to convert these columns into the right types for manipulation.

# %%
def convert_percentile_float(string):
    string = str(string)
    if string != 'nan':
        return float(string[:-1])
    return np.nan
percentiles_to_change = ['Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific']
for column in percentiles_to_change:
    df[column] = df[column].apply(convert_percentile_float)
df
# Out:
#                    State  TotalPop  Hispanic  White  Black  Native  Asian  \
# 0           Rhode Island   1053661     13.36  74.33   5.68    0.35   3.25
# 1         South Carolina   4777576      5.06  62.89  28.75    0.29   1.25
# 2           South Dakota    843190      3.24  82.50   1.42    9.42   1.02
# 3              Tennessee   6499615      4.72  73.49  18.28    0.23   1.41
# 4                  Texas  26538614     38.05  44.69  11.65    0.26   3.67
# 5                   Utah   2903379     13.47  79.41   1.02    1.08   2.20
# 6                   Utah   2903379     13.47  79.41   1.02    1.08   2.20
# 7                Vermont    626604      1.61  93.98   0.98    0.30   1.24
# 8               Virginia   8256630      8.01  63.27  20.18    0.21   5.46
# 9             Washington   6985464     11.14  72.04   3.38    1.41   7.02
# 10         West Virginia   1851420      1.29  92.18   3.66    0.15   0.68
# 11             Wisconsin   5742117      6.68  79.86   8.20    0.95   2.40
# ...

# %% [markdown]
# ## Regex to the Rescue

# %% [markdown]
# 5. Use regex to turn the `Income` column into a format that is ready for conversion into a numerical type.

# %%
import regex as re
def convert_income_float(string):
    string = str(string)
    pattern = r"[$, ]"
    string = re.sub(pattern, '', string)
    return float(string)
df['Income'] = df['Income'].apply(convert_income_float)
df
# Out:
#                    State  TotalPop  Hispanic  White  Black  Native  Asian  \
# 0           Rhode Island   1053661     13.36  74.33   5.68    0.35   3.25
# 1         South Carolina   4777576      5.06  62.89  28.75    0.29   1.25
# 2           South Dakota    843190      3.24  82.50   1.42    9.42   1.02
# 3              Tennessee   6499615      4.72  73.49  18.28    0.23   1.41
# 4                  Texas  26538614     38.05  44.69  11.65    0.26   3.67
# 5                   Utah   2903379     13.47  79.41   1.02    1.08   2.20
# 6                   Utah   2903379     13.47  79.41   1.02    1.08   2.20
# 7                Vermont    626604      1.61  93.98   0.98    0.30   1.24
# 8               Virginia   8256630      8.01  63.27  20.18    0.21   5.46
# 9             Washington   6985464     11.14  72.04   3.38    1.41   7.02
# 10         West Virginia   1851420      1.29  92.18   3.66    0.15   0.68
# 11             Wisconsin   5742117      6.68  79.86   8.20    0.95   2.40
# ...

# %% [markdown]
# 6. Look at the `GenderPop` column. We are going to want to separate this into two columns, the `Men` column, and the `Women` column.
#
#    Split the column into those two new columns using `str.split` and separating out those results.

# %%
df['GenderPop'] = df['GenderPop'].str.split('_')
df['Men'] = [round(int(string[0][:-1])) if string[0] != 'M' else None for string in df['GenderPop']]
df['Women'] = [round(int(string[1][:-1])) if string[1] != 'F' else None for string in df['GenderPop']]
columns = columns + ['Men', 'Women']
columns.remove('GenderPop')
df = df[columns]
df
# Out:
#                    State  TotalPop  Hispanic  White  Black  Native  Asian  \
# 0           Rhode Island   1053661     13.36  74.33   5.68    0.35   3.25
# 1         South Carolina   4777576      5.06  62.89  28.75    0.29   1.25
# 2           South Dakota    843190      3.24  82.50   1.42    9.42   1.02
# 3              Tennessee   6499615      4.72  73.49  18.28    0.23   1.41
# 4                  Texas  26538614     38.05  44.69  11.65    0.26   3.67
# 5                   Utah   2903379     13.47  79.41   1.02    1.08   2.20
# 6                   Utah   2903379     13.47  79.41   1.02    1.08   2.20
# 7                Vermont    626604      1.61  93.98   0.98    0.30   1.24
# 8               Virginia   8256630      8.01  63.27  20.18    0.21   5.46
# 9             Washington   6985464     11.14  72.04   3.38    1.41   7.02
# 10         West Virginia   1851420      1.29  92.18   3.66    0.15   0.68
# 11             Wisconsin   5742117      6.68  79.86   8.20    0.95   2.40
# ...

# %% [markdown]
# 7. Now you should have the columns you need to make the graph and make sure your boss does not slam a ruler angrily on your desk because you've wasted your whole day cleaning your data with no results to show!
#
#    Use matplotlib to make a scatterplot!
#
#    ```py
#    plt.scatter(the_women_column, the_income_column)
#    ```
#
#    Remember to call `plt.show()` to see the graph!

# %%
sns.scatterplot(data = df, x = 'Women', y = 'Income')
plt.show()

# %% [markdown]
# 8. You want to double check your work. You know from experience that these monstrous csv files probably have `nan` values in them! Print out your column with the number of women per state to see.
#
#    We can fill in those `nan`s by using pandas' `.fillna()` function.
#
#    You have the `TotalPop` per state, and you have the `Men` per state. As an estimate for the `nan` values in the `Women` column, you could use the `TotalPop` of that state minus the `Men` for that state.
#
#    Print out the `Women` column after filling the `nan` values to see if it worked!

# %%
df['Women'] = df['Women'].fillna(df['TotalPop'] - df['Men'])
df
# Out:
# /var/folders/qn/18wdgjxd7pq9_v70cxrqmfyh0000gn/T/ipykernel_43993/222122429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Women'] = df['Women'].fillna(df['TotalPop'] - df['Men'])
#                    State  TotalPop  Hispanic  White  Black  Native  Asian  \
# 0           Rhode Island   1053661     13.36  74.33   5.68    0.35   3.25
# 1         South Carolina   4777576      5.06  62.89  28.75    0.29   1.25
# 2           South Dakota    843190      3.24  82.50   1.42    9.42   1.02
# 3              Tennessee   6499615      4.72  73.49  18.28    0.23   1.41
# 4                  Texas  26538614     38.05  44.69  11.65    0.26   3.67
# 5                   Utah   2903379     13.47  79.41   1.02    1.08   2.20
# ...

# %% [markdown]
# 9. We forgot to check for duplicates! Use `.duplicated()` on your `census` DataFrame to see if we have duplicate rows in there.

# %%
print(df.duplicated().value_counts())
df
# Out:
# False    51
# True      9
# Name: count, dtype: int64
#                    State  TotalPop  Hispanic  White  Black  Native  Asian  \
# 0           Rhode Island   1053661     13.36  74.33   5.68    0.35   3.25
# 1         South Carolina   4777576      5.06  62.89  28.75    0.29   1.25
# 2           South Dakota    843190      3.24  82.50   1.42    9.42   1.02
# 3              Tennessee   6499615      4.72  73.49  18.28    0.23   1.41
# 4                  Texas  26538614     38.05  44.69  11.65    0.26   3.67
# 5                   Utah   2903379     13.47  79.41   1.02    1.08   2.20
# 6                   Utah   2903379     13.47  79.41   1.02    1.08   2.20
# 7                Vermont    626604      1.61  93.98   0.98    0.30   1.24
# 8               Virginia   8256630      8.01  63.27  20.18    0.21   5.46
# 9             Washington   6985464     11.14  72.04   3.38    1.41   7.02
# 10         West Virginia   1851420      1.29  92.18   3.66    0.15   0.68
# ...

# %% [markdown]
# 10. Drop those duplicates using the `.drop_duplicates()` function.

# %%
df = df.drop_duplicates()
df
# Out:
#                    State  TotalPop  Hispanic  White  Black  Native  Asian  \
# 0           Rhode Island   1053661     13.36  74.33   5.68    0.35   3.25
# 1         South Carolina   4777576      5.06  62.89  28.75    0.29   1.25
# 2           South Dakota    843190      3.24  82.50   1.42    9.42   1.02
# 3              Tennessee   6499615      4.72  73.49  18.28    0.23   1.41
# 4                  Texas  26538614     38.05  44.69  11.65    0.26   3.67
# 5                   Utah   2903379     13.47  79.41   1.02    1.08   2.20
# 7                Vermont    626604      1.61  93.98   0.98    0.30   1.24
# 8               Virginia   8256630      8.01  63.27  20.18    0.21   5.46
# 9             Washington   6985464     11.14  72.04   3.38    1.41   7.02
# 10         West Virginia   1851420      1.29  92.18   3.66    0.15   0.68
# 11             Wisconsin   5742117      6.68  79.86   8.20    0.95   2.40
# 12              Maryland   5930538      8.47  52.68  30.68    0.20   5.33
# ...

# %% [markdown]
# 11. Make the scatterplot again. Now, it should be perfect! Your job is secure, for now.

# %%
sns.scatterplot(data = df, x = 'Women', y = 'Income')
plt.xlabel('Women population')
plt.ylabel('Total income')
plt.title('Women and Income')
plt.show()

# %% [markdown]
# ## Histogram of Races

# %% [markdown]
# 12. Now your boss wants you to make a bunch of histograms out of the race data that you have. Look at the `.columns` again to see what the race categories are.

# %%
df.columns
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'Men', 'Women'],
#       dtype='object')

# %% [markdown]
# 13. Try to make a histogram for each one!
#
#     You will have to get the columns into the numerical format, and those percentage signs will have to go.
#
#     Don't forget to fill the `nan` values with something that makes sense! You probably dropped the duplicate rows when making your last graph, but it couldn't hurt to check for duplicates again.

# %%
df['Pacific'] = df['Pacific'].fillna(100 - df['Hispanic'] - df['White'] - df['Black'] - df['Asian'] - df['Native'])
df
def create_hist(column):
    plt.hist(df[column])
    plt.title(f'Hisotgram of percentage of {column} per State')
    plt.show()
    plt.clf()
for column in ['Hispanic','White','Black','Asian','Pacific','Native']:
    create_hist(column)
# Out:
# /var/folders/qn/18wdgjxd7pq9_v70cxrqmfyh0000gn/T/ipykernel_43993/3381154719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pacific'] = df['Pacific'].fillna(100 - df['Hispanic'] - df['White'] - df['Black'] - df['Asian'] - df['Native'])

# %% [markdown]
# ## Get Creative

# %% [markdown]
# 14. Phew. You've definitely impressed your boss on your first day of work.
#
#     But is there a way you really convey the power of pandas and Python over the drudgery of `csv` and Excel?
#
#     Try to make some more interesting graphs to show your boss, and the world! You may need to clean the data even more to do it, or the cleaning you have already done may give you the ease of manipulation you've been searching for.
